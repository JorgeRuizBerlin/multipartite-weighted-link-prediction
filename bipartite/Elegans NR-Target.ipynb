# %%
import numpy as np
import matplotlib.pyplot as plt

import b_datasets as ds
import b_val as val
import b_lcp
import b_mi
import b_si
import b_probas as probas

# %%
fraction = 0.1
loops = 100
verbose=True
plot=False

# %%
# Elegans data (multipartite)
s_nt, nt_nr, nr_t = ds.load_elegans_data()

# %%
# Giant component of s_nt
s_nt_giant = ds.giant_component_bp(s_nt)

# %%
# Other datasets (bipartite only)
x_e = ds.load_enzyme_data()
x_g = ds.load_gpcr_data()
x_ic = ds.load_ion_channel_data()

# %%
# Precompute links to delete for all datasets
links_to_del_s_nt = val.get_links_to_del(s_nt, fraction=fraction, loops=loops)
links_to_del_nt_nr = val.get_links_to_del(nt_nr, fraction=fraction, loops=loops)
links_to_del_nr_t = val.get_links_to_del(nr_t, fraction=fraction, loops=loops)

# %%
links_to_del_s_nt_giant = val.get_links_to_del(s_nt_giant, fraction=fraction, loops=loops)

# %%
links_to_del_e = val.get_links_to_del(x_e, fraction=fraction, loops=loops)
links_to_del_g = val.get_links_to_del(x_g, fraction=fraction, loops=loops)
links_to_del_ic = val.get_links_to_del(x_ic, fraction=fraction, loops=loops)

# %%
# CN
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('cn',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.24 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# [0.1169879  0.86593115]
# [0.02179232 0.0128061 ]

# %%
# LCL
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('lcl',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# [0.31082958 0.88018405]
# [0.02900606 0.01314023]

# %%
# JC
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('jc',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.34 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.29 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.25 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.35 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.28 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.33 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.26 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.27 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.31 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.26 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# [0.1482861  0.85050834]
# [0.02080745 0.01329568]

# %%
# CJC
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('cjc',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.24 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.29 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# [0.29736094 0.87869819]
# [0.02878365 0.01331719]

# %%
# CRA
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('cra',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.29 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.24 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.25 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.31 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.30 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.23 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.29 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.26 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.22 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.20 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# [0.32262559 0.90058676]
# [0.0294761  0.01207705]

# %%
# CAR
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('car',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.19 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.29 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# [0.29281287 0.8758779 ]
# [0.02960399 0.01301828]

# %%
# RA
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('ra',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.15 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.16 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.17 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.26 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# [0.0713521  0.87334046]
# [0.01053525 0.01158198]

# %%
# CPA
r = val.cross_val(b_lcp.bipartite_lcp_single, nr_t, links_to_del_nr_t, *('cpa',), 
                   mode='lcp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 2 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 3 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 4 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 5 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 6 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 7 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 8 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 9 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 10 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 11 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 12 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 13 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 14 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 15 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 16 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 17 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 18 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 19 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 20 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 21 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 22 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 23 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 24 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 25 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 26 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 27 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 28 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 29 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 30 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 31 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 32 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 33 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 34 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 35 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 36 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 37 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 38 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 39 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 40 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 41 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 42 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 43 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 44 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 45 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 46 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 47 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 48 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 49 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 50 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 51 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 52 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 53 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 54 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 55 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 56 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 57 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 58 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 59 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 60 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 61 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 62 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 63 of 100
# Computing bipartite LCP
# 99.78 %, 0.21 minutes
# Trial 64 of 100
# Computing bipartite LCP
# 99.78 %, 0.18 minutes
# Trial 65 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 66 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 67 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 68 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 69 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 70 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 71 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 72 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 73 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 74 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 75 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 76 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 77 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 78 of 100
# Computing bipartite LCP
# 99.78 %, 0.14 minutes
# Trial 79 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 80 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 81 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 82 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 83 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 84 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 85 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 86 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 87 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 88 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 89 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 90 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 91 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 92 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 93 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 94 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 95 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 96 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 97 of 100
# Computing bipartite LCP
# 99.78 %, 0.13 minutes
# Trial 98 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 99 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# Trial 100 of 100
# Computing bipartite LCP
# 99.78 %, 0.12 minutes
# [0.29277863 0.87563495]
# [0.02963502 0.01303746]

# %%
# MI links
r = val.cross_val(b_si.si_scores, nr_t, links_to_del_nr_t, *(probas.proba_comb_links_all, b_mi.mi_lcl_cc), 
                   mode='si_bp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 2 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 3 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 4 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 5 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 6 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 7 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 8 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 9 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 10 of 100
# Computing mutual information
# 98.78 %, 1.20 minutes
# Trial 11 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 12 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 13 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 14 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 15 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 16 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 17 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 18 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 19 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 20 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 21 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 22 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 23 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 24 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 25 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 26 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 27 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 28 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 29 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 30 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 31 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 32 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 33 of 100
# Computing mutual information
# 98.78 %, 1.15 minutes
# Trial 34 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 35 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 36 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 37 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 38 of 100
# Computing mutual information
# 98.78 %, 1.14 minutes
# Trial 39 of 100
# Computing mutual information
# 98.78 %, 1.14 minutes
# Trial 40 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 41 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 42 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 43 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 44 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 45 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 46 of 100
# Computing mutual information
# 98.78 %, 1.28 minutes
# Trial 47 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 48 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 49 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 50 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 51 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 52 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 53 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 54 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 55 of 100
# Computing mutual information
# 98.78 %, 1.27 minutes
# Trial 56 of 100
# Computing mutual information
# 98.78 %, 1.34 minutes
# Trial 57 of 100
# Computing mutual information
# 98.78 %, 1.26 minutes
# Trial 58 of 100
# Computing mutual information
# 98.78 %, 1.40 minutes
# Trial 59 of 100
# Computing mutual information
# 98.78 %, 1.28 minutes
# Trial 60 of 100
# Computing mutual information
# 98.78 %, 1.25 minutes
# Trial 61 of 100
# Computing mutual information
# 98.78 %, 1.26 minutes
# Trial 62 of 100
# Computing mutual information
# 98.78 %, 1.19 minutes
# Trial 63 of 100
# Computing mutual information
# 98.78 %, 1.26 minutes
# Trial 64 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 65 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 66 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 67 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 68 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 69 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 70 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 71 of 100
# Computing mutual information
# 98.78 %, 1.25 minutes
# Trial 72 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 73 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 74 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 75 of 100
# Computing mutual information
# 98.78 %, 1.39 minutes
# Trial 76 of 100
# Computing mutual information
# 98.78 %, 1.35 minutes
# Trial 77 of 100
# Computing mutual information
# 98.78 %, 1.21 minutes
# Trial 78 of 100
# Computing mutual information
# 98.78 %, 1.19 minutes
# Trial 79 of 100
# Computing mutual information
# 98.78 %, 1.17 minutes
# Trial 80 of 100
# Computing mutual information
# 98.78 %, 1.17 minutes
# Trial 81 of 100
# Computing mutual information
# 98.78 %, 1.21 minutes
# Trial 82 of 100
# Computing mutual information
# 98.78 %, 1.18 minutes
# Trial 83 of 100
# Computing mutual information
# 98.78 %, 1.32 minutes
# Trial 84 of 100
# Computing mutual information
# 98.78 %, 1.18 minutes
# Trial 85 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 86 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 87 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 88 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 89 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 90 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 91 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 92 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 93 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 94 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 95 of 100
# Computing mutual information
# 98.78 %, 1.05 minutes
# Trial 96 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 97 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 98 of 100
# Computing mutual information
# 98.78 %, 1.22 minutes
# Trial 99 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 100 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# [0.2309925  0.88673272]
# [0.02755171 0.01307157]

# %%
# MI degree
r = val.cross_val(b_si.si_scores, nr_t, links_to_del_nr_t, *(probas.proba_comb_deg_all, b_mi.mi_lcl_cc), 
                   mode='si_bp', loops=loops, verbose=verbose, plot=plot)
print(np.mean(r, axis=0))
print(np.std(r, axis=0))
# Out:
# Trial 1 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 2 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 3 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 4 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 5 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 6 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 7 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 8 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 9 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 10 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 11 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 12 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 13 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 14 of 100
# Computing mutual information
# 98.78 %, 1.24 minutes
# Trial 15 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 16 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 17 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 18 of 100
# Computing mutual information
# 98.78 %, 1.05 minutes
# Trial 19 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 20 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 21 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 22 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 23 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 24 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 25 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 26 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 27 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 28 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 29 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 30 of 100
# Computing mutual information
# 98.78 %, 1.23 minutes
# Trial 31 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 32 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 33 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 34 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 35 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 36 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 37 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 38 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 39 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 40 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 41 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 42 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 43 of 100
# Computing mutual information
# 98.78 %, 1.40 minutes
# Trial 44 of 100
# Computing mutual information
# 98.78 %, 1.16 minutes
# Trial 45 of 100
# Computing mutual information
# 98.78 %, 1.33 minutes
# Trial 46 of 100
# Computing mutual information
# 98.78 %, 1.17 minutes
# Trial 47 of 100
# Computing mutual information
# 98.78 %, 1.23 minutes
# Trial 48 of 100
# Computing mutual information
# 98.78 %, 1.15 minutes
# Trial 49 of 100
# Computing mutual information
# 98.78 %, 1.15 minutes
# Trial 50 of 100
# Computing mutual information
# 98.78 %, 1.16 minutes
# Trial 51 of 100
# Computing mutual information
# 98.78 %, 1.18 minutes
# Trial 52 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 53 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 54 of 100
# Computing mutual information
# 98.78 %, 1.11 minutes
# Trial 55 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 56 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 57 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 58 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 59 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 60 of 100
# Computing mutual information
# 98.78 %, 1.05 minutes
# Trial 61 of 100
# Computing mutual information
# 98.78 %, 1.21 minutes
# Trial 62 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 63 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 64 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 65 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 66 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 67 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 68 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 69 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 70 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 71 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 72 of 100
# Computing mutual information
# 98.78 %, 1.05 minutes
# Trial 73 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 74 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 75 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 76 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 77 of 100
# Computing mutual information
# 98.78 %, 1.21 minutes
# Trial 78 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 79 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 80 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 81 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 82 of 100
# Computing mutual information
# 98.78 %, 1.09 minutes
# Trial 83 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 84 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 85 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 86 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 87 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 88 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 89 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 90 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 91 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 92 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 93 of 100
# Computing mutual information
# 98.78 %, 1.06 minutes
# Trial 94 of 100
# Computing mutual information
# 98.78 %, 1.07 minutes
# Trial 95 of 100
# Computing mutual information
# 98.78 %, 1.23 minutes
# Trial 96 of 100
# Computing mutual information
# 98.78 %, 1.08 minutes
# Trial 97 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 98 of 100
# Computing mutual information
# 98.78 %, 1.10 minutes
# Trial 99 of 100
# Computing mutual information
# 98.78 %, 1.03 minutes
# Trial 100 of 100
# Computing mutual information
# 98.78 %, 1.02 minutes
# [0.30843072 0.88542767]
# [0.02772377 0.0133483 ]
